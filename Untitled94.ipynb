# %% [markdown]
# <a href="https://colab.research.google.com/github/nida07/college-chatbot-RNN/blob/master/Untitled94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#tensorflow is an open source for the ml framework, helping in training, building the model which provide API keras

# %%
import json

with open('/content/drive/MyDrive/chatbot/intentsupdated.json', 'r') as file:
    intents = json.load(file)

# Preprocess data
patterns = []
responses = []
tags = []

for intent in intents['intents']:
    for pattern in intent['patterns']:
        patterns.append(pattern)
        responses.append(intent['responses'][0])  # We'll just use the first response for simplicity
        tags.append(intent['tag'])
# add more tag

# %%
print(tags)
# Out:
# ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'creator', 'crea
# ...

# %%
# padding sequences to a fixed length, tokenizing text data
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Tokenize input patterns
tokenizer = Tokenizer()
#vocabulary, input patterns, and numerical indices based on word repetition
tokenizer.fit_on_texts(patterns)
#  word index dictionary from the tokenizer
word_index = tokenizer.word_index

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(patterns)
# max number of sequences in each length and find the maximum and it set as pad_sequences
max_sequence_len = max([len(seq) for seq in sequences])

# Pad sequences to have same length add 0 after ie; padding = 'post' so each sequence will be same length
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_len, padding='post')

# %%
# LabelEncoder is used to convert categorical labels into numerical labels.
from sklearn.preprocessing import LabelEncoder

# Convert tags to numerical labels
label_encoder = LabelEncoder()
encoded_tags = label_encoder.fit_transform(tags)

# Train the model
# model.fit(padded_sequences, encoded_tags, epochs=100, verbose=1)

# %%
# model.summary()

# %%
# Sequential is a class for creating a linear stack of layers. Embedding, LSTM,
# and Dense are classes representing the layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# layers 3
# Embedding(input dim, output dimension, input_length)
# lstm uses 128 memory cell
# dense (tot no of tags , activation function)


# Define model architecture
model = Sequential([
    Embedding(len(word_index) + 1, 64, input_length=max_sequence_len),
    LSTM(128),
    Dense(len(tags), activation='softmax')
])

# adaptive moment estimation increase learning rate
# loss is multiclass integer-based, optimizer update model weight, accuracy evaluation
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model(input,target label,epoch verbos)
history_rnn=model.fit(padded_sequences, encoded_tags, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 39/39 [==============================] - 6s 78ms/step - loss: 5.5941 - accuracy: 0.0395
# Epoch 2/200
# 39/39 [==============================] - 3s 82ms/step - loss: 3.6886 - accuracy: 0.0306
# Epoch 3/200
# 39/39 [==============================] - 1s 13ms/step - loss: 3.6735 - accuracy: 0.0362
# Epoch 4/200
# 39/39 [==============================] - 2s 45ms/step - loss: 3.6664 - accuracy: 0.0419
# Epoch 5/200
# 39/39 [==============================] - 1s 16ms/step - loss: 3.6688 - accuracy: 0.0443
# Epoch 6/200
# 39/39 [==============================] - 1s 21ms/step - loss: 3.6592 - accuracy: 0.0419
# Epoch 7/200
# 39/39 [==============================] - 0s 8ms/step - loss: 3.6607 - accuracy: 0.0370
# Epoch 8/200
# 39/39 [==============================] - 1s 27ms/step - loss: 3.6653 - accuracy: 0.0354
# Epoch 9/200
# 39/39 [==============================] - 1s 17ms/step - loss: 3.6636 - accuracy: 0.0411
# Epoch 10/200
# ...

# %%
# model.summary()

# %%
from sklearn.preprocessing import LabelEncoder

# Convert tags to numerical labels
label_encoder = LabelEncoder()
encoded_tags = label_encoder.fit_transform(tags)

# # Train the model
# model.fit(padded_sequences, encoded_tags, epochs=100, verbose=1)

# %%
import numpy as np

def chat():
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'quit':
            print("see you later!!")
            break

        # Tokenize user input
        input_seq = tokenizer.texts_to_sequences([user_input])
        padded_input_seq = pad_sequences(input_seq, maxlen=max_sequence_len, padding='post')

        # Predict probabilities for each class
        predicted_probs = model.predict(padded_input_seq)

        # Get predicted tag
        predicted_tag_index = np.argmax(predicted_probs)
        predicted_tag = label_encoder.inverse_transform([predicted_tag_index])[0]

        # Get response
        responses_list = [responses[i] for i, tag in enumerate(tags) if tag == predicted_tag]
        print("Bot:", np.random.choice(responses_list))
        # issue cleared

# Start chatting
chat()
# Out:
# You: quit
# see you later!!

# %% [markdown]
# new idea

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json

with open('/content/drive/MyDrive/chatbot/intentsupdated.json', 'r') as file:
    intents = json.load(file)

# # Preprocess data
# patterns = []
# responses = []
# tags = []

# for intent in intents['intents']:
#     for pattern in intent['patterns']:
#         patterns.append(pattern)
#         responses.append(intent['responses'][0])  # We'll just use the first response for simplicity
#         tags.append(intent['tag'])
# # add more tag

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import numpy as np


nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
intents = intents['intents']
words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
import random
import numpy as np

training = []
output_empty = [0] * len(classes)

for document in documents:
    bag = []
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append((bag, output_row))

random.shuffle(training)

X_train = np.array([item[0] for item in training])
y_train = np.array([item[1] for item in training])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential([
    Dense(128, input_shape=(len(X_train[0]),), activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(len(y_train[0]), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=200, batch_size=5, verbose=1)
history_fnn = model.fit(X_train, y_train, epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 249/249 [==============================] - 2s 3ms/step - loss: 3.6052 - accuracy: 0.0765
# Epoch 2/200
# 249/249 [==============================] - 1s 3ms/step - loss: 3.2067 - accuracy: 0.1965
# Epoch 3/200
# 249/249 [==============================] - 1s 3ms/step - loss: 2.5982 - accuracy: 0.3502
# Epoch 4/200
# 249/249 [==============================] - 1s 3ms/step - loss: 2.0507 - accuracy: 0.4791
# Epoch 5/200
# 249/249 [==============================] - 1s 3ms/step - loss: 1.6696 - accuracy: 0.5725
# Epoch 6/200
# 249/249 [==============================] - 1s 3ms/step - loss: 1.3876 - accuracy: 0.6320
# Epoch 7/200
# 249/249 [==============================] - 1s 3ms/step - loss: 1.1786 - accuracy: 0.6957
# Epoch 8/200
# 249/249 [==============================] - 1s 3ms/step - loss: 1.0800 - accuracy: 0.6997
# Epoch 9/200
# 249/249 [==============================] - 1s 3ms/step - loss: 0.8997 - accuracy: 0.7528
# Epoch 10/200
# ...

# %%
def chat():
    print("Start talking with the bot (type quit to stop)!")
    while True:
        inp = input("You: ")
        if inp.lower() == "quit":
            break

        results = model.predict([bag_of_words(inp, words)])
        results_index = np.argmax(results)
        tag = classes[results_index]

        for intent in intents:
            if intent['tag'] == tag:
                print(f"Bot: {random.choice(intent['responses'])}")
def bag_of_words(s, words):
    bag = [0] * len(words)
    s_words = nltk.word_tokenize(s)
    s_words = [lemmatizer.lemmatize(word.lower()) for word in s_words]

    for se in s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1

    return np.array(bag).reshape(1, -1)  # Reshape to a 2D array with one row


chat()
# Out:
# Start talking with the bot (type quit to stop)!
# You: quit

# %%
# history_rnn =model.fit(padded_sequences, encoded_tags, epochs=200, verbose=1)

# %%
# history_fnn = model.fit(X_train, y_train, epochs=200, batch_size=5, verbose=1)
# #

# %%
import matplotlib.pyplot as plt

# Plotting loss curve for RNN model
plt.plot(history_rnn.history['loss'], label='RNN Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Curve for RNN Model')
plt.legend()
plt.show()

# Plotting loss curve for FNN model
plt.plot(history_fnn.history['loss'], label='FNN Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Curve for FNN Model')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting loss curves for both RNN and FNN models
plt.plot(history_rnn.history['loss'], label='RNN Training Loss', color='blue')
plt.plot(history_fnn.history['loss'], label='FNN Training Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.title('Training Loss Curves for RNN and FNN Models')
plt.legend()
plt.show()

# %%
# Plotting accuracy curve for both RNN and FNN models
plt.plot(history_rnn.history['accuracy'], label='RNN Training Accuracy', color='blue')
plt.plot(history_fnn.history['accuracy'], label='FNN Training Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# plt.title('Training Accuracy Curves for RNN and FNN Models')
plt.legend()
plt.show()

# %%
# # Create test_data list
# test_data = []

# # Iterate over intents
# for intent in intents:
#     tag = intent['tag']
#     patterns = intent['patterns']
#     responses = intent['responses']

#     # Add each pattern-response pair to test_data
#     for pattern in patterns:
#         test_data.append((pattern, tag))

# # Print the test_data to verify
# print(test_data)

# %%
# # Assume you have a trained RNN model named rnn_model

# # Create an empty list to store generated responses
# generated_responses = []

# # Iterate over the test data
# for input_message, reference_response in test_data:
#     # Generate response using the RNN model
#     generated_response = rnn_model.generate_response(input_message)

#     # Append the generated response to the list
#     generated_responses.append(generated_response)

# # Now you can analyze the generated_responses list as needed

# %%
# # Assuming you have a test dataset named test_data with input messages and reference responses
# # test_data = [(input_message_1, reference_response_1), (input_message_2, reference_response_2), ...]

# correct_responses = 0
# total_responses = len(test_data)

# for input_message, reference_response in test_data:
#     # Generate response using the RNN model
#     generated_response = rnn_model.generate_response(input_message)

#     # Check if the generated response matches the reference response
#     if generated_response == reference_response:
#         correct_responses += 1

# # Calculate response accuracy
# response_accuracy = (correct_responses / total_responses) * 100

# print("Response Accuracy: {:.2f}%".format(response_accuracy))
